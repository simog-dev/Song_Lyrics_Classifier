# %% [markdown]
# ## Importing Modules

# %%
import re
import nltk
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Setting environment to ignore future warnings
import warnings
warnings.simplefilter('ignore')

# Downloading required data
nltk.download("wordnet")

# Downloading & Loading NLTK modelus
nltk.download('punkt')
nltk.download('wordnet')
nltk.download("stopwords")
nltk.download('maxent_ne_chunker')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# ## Loading Data

# %% [markdown]
# **Reading Clean Data**

# %%
import pandas as pd
df_clean = pd.read_csv('clean_data.csv')
df_clean.head()
# Out:
#    year           artist  genre  \
# 0  2009  beyonce-knowles      7
# 1  2009  beyonce-knowles      7
# 2  2009  beyonce-knowles      7
# 3  2009  beyonce-knowles      7
# 4  2009  beyonce-knowles      7
#
#                                         lyrics_clean   len
# 0  oh baby know gonna cut right chase woman made ...   966
# 1  playin everything easy like seem sure still wa...   668
# 2  search tenderness hard find love need live loo...   462
# 3  oh oh oh oh oh oh verse 1 wrote book stand tit...  1230
# 4  party people people party popping sitting arou...   887

# %%
input_feature = df_clean.drop(['genre','artist'],axis=1)
output_feature = df_clean.genre

# %%
convert_dict = {'year': str,
                'len': str
                }
 
input_feature = input_feature.astype(convert_dict)
input_feature.dtypes
# Out:
# year            object
# lyrics_clean    object
# len             object
# dtype: object

# %%
input_feature["combined"] = input_feature["year"].str.cat(input_feature[["lyrics_clean", "len"]].astype(str), sep=" ")
input_feature.drop(['year','lyrics_clean','len'],axis=1,inplace=True)

# %%
len(set(output_feature))
# Out:
# 10

# %%
input_feature.shape[0]
# Out:
# 192683

# %%
import time
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# Importing Models
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB

# Importing Evaluation matrces
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

from sklearn.ensemble import RandomForestClassifier



vectorizers = [TfidfVectorizer(max_features=1500, stop_words='english')]

samplers = [None]
from sklearn.naive_bayes import GaussianNB
models = []
models.append(('ANN', None))
models.append(('Gaussian NB',GaussianNB()))
# models.append(('SVM(Non-linear Kernel)', SVC(kernel='rbf', random_state=0)  ))
models.append(('Random Forest', RandomForestClassifier()))

# %%
acc = []
pre = []
rec = []
f1 = []
con = []
vectorization_tec=[]
sampling_tec = []
models_name = []
for vec in vectorizers:
    X = vec.fit_transform(input_feature.combined).toarray()
    Y = output_feature
    
    for sampler in samplers:
      if sampler:
        X, Y = sampler.fit_resample(X,Y)
      X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
      i = 0
      for name, model in models:
        i = i+1
        start_time = time.time()
        if name == "ANN":
          
          models_name.append(name)
          vectorization_tec.append(type(vec).__name__)
          if sampler:
            sampling_tec.append(type(sampler).__name__)
          else:
            sampling_tec.append("Withinout Sampling")

            

          y_tr = pd.get_dummies(y_train)
          y_ts = pd.get_dummies(y_test)
                
          mapper = dict([[i, j] for i, j in zip(y_tr.columns, list(range(len(y_tr.columns))))])
                
          rnn = Sequential()
          rnn.add(Dense(8, activation="relu", input_dim=1500))
          rnn.add(Dense(16))
          rnn.add(Dropout(0.2))
          rnn.add(Dense(16))
          rnn.add(Dense(y_tr.shape[1], activation="softmax"))
          rnn.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")
          rnn.fit(X_train, y_tr, epochs=10, validation_data=(X_test, y_ts))
          y_pred = [np.argmax(i) for i in rnn.predict(X_test)]
          y_ts = y_ts.idxmax(axis=1).map(mapper)
                
                # Accuracy
          accuracy = accuracy_score(y_ts, y_pred)
          acc.append(accuracy)
                # Precision
          precision = precision_score(y_ts, y_pred, average=None)
          pre.append(precision)
              
                # Recall
          recall = recall_score(y_ts, y_pred, average=None)
          rec.append(recall)
          # F1 Score
          f1_sco = f1_score(y_ts, y_pred, average=None)
          f1.append(f1_sco)
                # Confusion Matrix
          confusion_mat = confusion_matrix(y_ts, y_pred)
          con.append(confusion_mat)
                # Report
          report = classification_report(y_ts, y_pred)


          print("+","="*100,"+")
          print('\033[1m' + f"\t\t\t{i}-For {name} The Performance result is: " + '\033[0m')
          print("+","="*100,"+")
          print('Vectorization Technique : ', type(vec).__name__)   
          print("-"*50)
          print('Sampling Technique      : ', type(sampler).__name__)   
          print("-"*50)
          print('Accuracy : ', accuracy)   
          print("-"*50)
          print('F1 : ', f1_sco)
          print("-"*50)
          print('Reacll : ', recall)
          print("-"*50)
          print('Precision : ', precision)
          print("-"*50)
          print('Confusion Matrix....\n', confusion_mat)
          print("-"*50)
          print('Classification Report....\n', report)
          print("-"*50)
          print('Plotting Confusion Matrix...\n')
          plt.figure(figsize=(12, 9))
          sns.heatmap(confusion_mat, annot=True)
          plt.show()



          print("\t\t\t\t\t\t\t-----------------------------------------------------------")
          print(f"\t\t\t\t\t\t\t Time for detection ({name}) : {round((time.time() - start_time), 3)} seconds...")
          print("\t\t\t\t\t\t\t-----------------------------------------------------------")
          print()
        else:
          # Fitting model to the Training set
          clf = model
          clf.fit(X_train, y_train)

          models_name.append(name)
          vectorization_tec.append(type(vec).__name__)
          sampling_tec.append(type(sampler).__name__)
          # predict values
          y_pred = clf.predict(X_test)

                # Accuracy
          accuracy = accuracy_score(y_test, y_pred)
          acc.append(accuracy)
                # Precision
          precision = precision_score(y_test, y_pred, average=None)
          pre.append(precision)
                # Recall
          recall = recall_score(y_test, y_pred, average=None)
          rec.append(recall)
                # F1 Score
          f1_sco = f1_score(y_test, y_pred, average=None)
          f1.append(f1_sco)
                # Confusion Matrix
          confusion_mat = confusion_matrix(y_test, y_pred)
          con.append(confusion_mat)
                # Report
          report = classification_report(y_test, y_pred)


          print("+","="*100,"+")
          print('\033[1m' + f"\t\t\t{i}-For {name} The Performance result is: " + '\033[0m')
          print("+","="*100,"+")
          print('Vectorization Technique : ', type(vec).__name__)   
          print("-"*50)
          print('Sampling Technique      : ', type(sampler).__name__)   
          print("-"*50)
          print('Accuracy : ', accuracy)   
          print("-"*50)
          print('F1 : ', f1_sco)
          print("-"*50)
          print('Reacll : ', recall)
          print("-"*50)
          print('Precision : ', precision)
          print("-"*50)
          print('Confusion Matrix....\n', confusion_mat)
          print("-"*50)
          print('Classification Report....\n', report)
          print("-"*50)
          print('Plotting Confusion Matrix...\n')
          plt.figure(figsize=(12, 9))
          sns.heatmap(confusion_mat, annot=True)
          plt.show()



          print("\t\t\t\t\t\t\t-----------------------------------------------------------")
          print(f"\t\t\t\t\t\t\t Time for detection ({name}) : {round((time.time() - start_time), 3)} seconds...")
          print("\t\t\t\t\t\t\t-----------------------------------------------------------")
          print()
# Out:
# Epoch 1/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.2899 - accuracy: 0.5839 - val_loss: 1.2023 - val_accuracy: 0.6041
# Epoch 2/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.2024 - accuracy: 0.6045 - val_loss: 1.1915 - val_accuracy: 0.6070
# Epoch 3/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.1895 - accuracy: 0.6075 - val_loss: 1.1957 - val_accuracy: 0.6066
# Epoch 4/10
# 4818/4818 [==============================] - 14s 3ms/step - loss: 1.1809 - accuracy: 0.6102 - val_loss: 1.1864 - val_accuracy: 0.6099
# Epoch 5/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.1736 - accuracy: 0.6119 - val_loss: 1.1865 - val_accuracy: 0.6101
# Epoch 6/10
# 4818/4818 [==============================] - 14s 3ms/step - loss: 1.1683 - accuracy: 0.6131 - val_loss: 1.1842 - val_accuracy: 0.6110
# Epoch 7/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.1616 - accuracy: 0.6141 - val_loss: 1.1775 - val_accuracy: 0.6130
# Epoch 8/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.1568 - accuracy: 0.6156 - val_loss: 1.1748 - val_accuracy: 0.6122
# Epoch 9/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.1542 - accuracy: 0.6159 - val_loss: 1.1770 - val_accuracy: 0.6124
# Epoch 10/10
# 4818/4818 [==============================] - 15s 3ms/step - loss: 1.1500 - accuracy: 0.6169 - val_loss: 1.1765 - val_accuracy: 0.6110
# 1205/1205 [==============================] - 2s 2ms/step
# + ==================================================================================================== +
# 			1-For ANN The Performance result is:
# + ==================================================================================================== +
# Vectorization Technique :  TfidfVectorizer
# --------------------------------------------------
# Sampling Technique      :  NoneType
# --------------------------------------------------
# Accuracy :  0.6109972234475958
# --------------------------------------------------
# F1 :  [0.31794558 0.         0.         0.79120879 0.         0.06927176
#  0.58722081 0.25964392 0.01675042 0.71247856]
# --------------------------------------------------
# Reacll :  [0.21567814 0.         0.         0.7925636  0.         0.03768116
#  0.49159763 0.17857143 0.00847458 0.91190999]
# --------------------------------------------------
# Precision :  [0.60465116 0.         0.         0.78985861 0.         0.42857143
#  0.72902773 0.47554348 0.71428571 0.5846235 ]
# --------------------------------------------------
# Confusion Matrix....
#  [[  520     0     0    12     0    10    10    65     0  1794]
#  [    4     0     0   100     0     1    39   131     0   969]
#  [   10     0     0     4     0     0     8     8     0   257]
#  [    4     0     0  3240     0     0    16   166     0   662]
#  [    3     0     0    13     0     0    11    23     0   507]
#  [   47     0     0    31     0    39     6   106     0   806]
#  [    4     0     0    80     0     1  2077    40     0  2023]
#  [   49     0     0   366     0    18    67  1050     0  4330]
#  [    7     0     0    31     0     1     6    83     5   457]
#  [  212     0     0   225     0    21   609   536     2 16615]]
# --------------------------------------------------
# Classification Report....
#                precision    recall  f1-score   support
#
#            0       0.60      0.22      0.32      2411
#            1       0.00      0.00      0.00      1244
#            2       0.00      0.00      0.00       287
#            3       0.79      0.79      0.79      4088
#            4       0.00      0.00      0.00       557
#            5       0.43      0.04      0.07      1035
#            6       0.73      0.49      0.59      4225
#            7       0.48      0.18      0.26      5880
#            8       0.71      0.01      0.02       590
#            9       0.58      0.91      0.71     18220
#
#     accuracy                           0.61     38537
#    macro avg       0.43      0.26      0.28     38537
# weighted avg       0.57      0.61      0.55     38537
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# 							-----------------------------------------------------------
# 							 Time for detection (ANN) : 152.914 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			2-For Gaussian NB The Performance result is:
# + ==================================================================================================== +
# Vectorization Technique :  TfidfVectorizer
# --------------------------------------------------
# Sampling Technique      :  NoneType
# --------------------------------------------------
# Accuracy :  0.2008978384409788
# --------------------------------------------------
# F1 :  [0.25131376 0.09327731 0.02258163 0.68278221 0.04983953 0.12597838
#  0.50213742 0.08044424 0.06285907 0.0632799 ]
# --------------------------------------------------
# Reacll :  [0.33720448 0.0892283  0.51567944 0.73238748 0.23698384 0.16328502
#  0.56994083 0.04557823 0.15762712 0.03326015]
# --------------------------------------------------
# Precision :  [0.20029564 0.09771127 0.01154356 0.63947031 0.0278481  0.10254854
#  0.4487514  0.34227331 0.03925707 0.64951768]
# --------------------------------------------------
# Confusion Matrix....
#  [[ 813   28  964   71  183  136   59   23  102   32]
#  [  69  111  447  112  175   59  155   31   70   15]
#  [  26    3  148   10   35   16   24    3   13    9]
#  [  63  120  253 2994  138   54  111   93  189   73]
#  [  44   11  257   16  132   21   42    3   20   11]
#  [ 141   11  441   57   87  169   32   15   62   20]
#  [  78   65  968  145  307   57 2408   22  103   72]
#  [ 591  260 2266  449  771  351  344  268  496   84]
#  [  72   14  172   58   83   35   38   14   93   11]
#  [2162  513 6905  770 2829  750 2153  311 1221  606]]
# --------------------------------------------------
# Classification Report....
#                precision    recall  f1-score   support
#
#            0       0.20      0.34      0.25      2411
#            1       0.10      0.09      0.09      1244
#            2       0.01      0.52      0.02       287
#            3       0.64      0.73      0.68      4088
#            4       0.03      0.24      0.05       557
#            5       0.10      0.16      0.13      1035
#            6       0.45      0.57      0.50      4225
#            7       0.34      0.05      0.08      5880
#            8       0.04      0.16      0.06       590
#            9       0.65      0.03      0.06     18220
#
#     accuracy                           0.20     38537
#    macro avg       0.26      0.29      0.19     38537
# weighted avg       0.50      0.20      0.19     38537
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# 							-----------------------------------------------------------
# 							 Time for detection (Gaussian NB) : 10.437 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			3-For Random Forest The Performance result is:
# + ==================================================================================================== +
# Vectorization Technique :  TfidfVectorizer
# --------------------------------------------------
# Sampling Technique      :  NoneType
# --------------------------------------------------
# Accuracy :  0.6071567584399409
# --------------------------------------------------
# F1 :  [0.1607077  0.04354588 0.06       0.80358948 0.02131439 0.06776557
#  0.53318926 0.22647748 0.02640264 0.71069272]
# --------------------------------------------------
# Reacll :  [0.09041891 0.02250804 0.03135889 0.77764188 0.01077199 0.03574879
#  0.4087574  0.13979592 0.01355932 0.95301866]
# --------------------------------------------------
# Precision :  [0.7218543  0.66666667 0.69230769 0.83132845 1.         0.64912281
#  0.76653351 0.59608412 0.5        0.56661772]
# --------------------------------------------------
# Confusion Matrix....
#  [[  218     0     0    12     0     1    20    41     1  2118]
#  [    1    28     0    65     0     1    24    49     0  1076]
#  [    3     0     9     3     0     2     7     8     0   255]
#  [    0     3     1  3179     0     0     9   129     0   767]
#  [    0     0     0     6     6     1     5    10     0   529]
#  [   12     1     0    23     0    37     6    35     2   919]
#  [    0     1     1    69     0     0  1727    20     1  2406]
#  [   10     1     2   281     0    10    48   822     3  4703]
#  [    0     0     0    22     0     0     3    49     8   508]
#  [   58     8     0   164     0     5   404   216     1 17364]]
# --------------------------------------------------
# Classification Report....
#                precision    recall  f1-score   support
#
#            0       0.72      0.09      0.16      2411
#            1       0.67      0.02      0.04      1244
#            2       0.69      0.03      0.06       287
#            3       0.83      0.78      0.80      4088
#            4       1.00      0.01      0.02       557
#            5       0.65      0.04      0.07      1035
#            6       0.77      0.41      0.53      4225
#            7       0.60      0.14      0.23      5880
#            8       0.50      0.01      0.03       590
#            9       0.57      0.95      0.71     18220
#
#     accuracy                           0.61     38537
#    macro avg       0.70      0.25      0.27     38537
# weighted avg       0.64      0.61      0.53     38537
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# 							-----------------------------------------------------------
# 							 Time for detection (Random Forest) : 429.334 seconds...
# 							-----------------------------------------------------------
